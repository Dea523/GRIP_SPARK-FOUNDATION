# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans
# %matplotlib inline

# %%
df= pd.read_csv('Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head(6)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa

# %%
label=LabelEncoder()
df["Species"]=label.fit_transform(df["Species"])

# %%
df.head(4)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0

# %%
df.tail(8)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 142  143            5.8           2.7            5.1           1.9        2
# 143  144            6.8           3.2            5.9           2.3        2
# 144  145            6.7           3.3            5.7           2.5        2
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    int64
# dtypes: float64(4), int64(2)
# memory usage: 7.2 KB

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
#
#           Species
# count  150.000000
# mean     1.000000
# std      0.819232
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000

# %%
df.info == True
# Out:
# False

# %%
df.isnull == True
# Out:
# False

# %%
df.isnull().any()
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.shape
# Out:
# (150, 6)

# %%
df.dropna()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
##visulizing data
##Comparing dimension with species
sns.set_style('whitegrid')
sns.lmplot(y='SepalWidthCm',x='SepalLengthCm',data=df,fit_reg=False,hue='Species')
plt.title("Scatter Plot: Sepal Width vs Sepal Lenght(cm)")
# Out:
# Text(0.5, 1.0, 'Scatter Plot: Sepal Width vs Sepal Lenght(cm)')

# %%
sns.set_style('whitegrid')
sns.lmplot(y='PetalWidthCm',x='PetalLengthCm',data=df,fit_reg=False,hue='Species')
plt.title("Scatter Plot: Petal Width vs Petal Lenght(cm)")
plt.legend()

# %%
from sklearn import preprocessing 
X=df.iloc[:,:-1].values
css = []
for i in range(1,15): 
    #Building and fitting the model 
    kmeanModel = KMeans(n_clusters=i)
    kmeanModel.fit(X) 
    css.append(kmeanModel.inertia_)
print(css)
# Out:
# [281918.3243999999, 70616.29893333331, 31365.589670588233, 17777.233022759603, 11465.757653735633, 7923.778202564102, 5901.344164502165, 4578.056076883385, 3582.4282499999995, 2964.3307348901094, 2454.313681318681, 2072.770142191142, 1789.3905034965035, 1577.7336868686868]

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(10,5))
plt.plot(range(1,15),css)
plt.title('The elbow method',size=15)
plt.xlabel('Number of clusters',size=12)
plt.ylabel('WCSS',size=12) # Within cluster sum of squares
plt.show()

# %%
df.head(1)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species  \
# 0   1            5.1           3.5            1.4           0.2        0
#
#    Cluster
# 0        0

# %%
sns.pairplot(data=df,hue='PetalWidthCm')

# %%
kmeans=KMeans(n_clusters=3)
classifier=kmeans.fit_predict(X)

df=df.copy()
df['Cluster']=classifier
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species  \
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0
#
#    Cluster
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
#cluster visulization
sns.set_style('whitegrid')
plt.figure(figsize=(7,6))
plt.title('Clusters w.r.t. features Sepal length and Petal length \n')

plt.scatter(X[classifier==0,0],X[classifier==0,2],s=70,c='green',label='Iris-Setosa')
plt.scatter(X[classifier==1,0],X[classifier==1,2],s=70,c='yellow',label='Iris-Virginica')
plt.scatter(X[classifier==2,0],X[classifier==2,2],s=70,c='purple',label='Iris-Versicolor')

plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,2],s=100,c='black',label='Centroids')

plt.legend()
plt.show()

# %%
df.nunique()
# Out:
# Id               150
# SepalLengthCm     35
# SepalWidthCm      23
# PetalLengthCm     43
# PetalWidthCm      22
# Species            3
# Cluster            3
# dtype: int64

# %%
sns.pairplot(data=df,hue='SepalWidthCm')

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
